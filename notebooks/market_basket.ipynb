# %% [markdown]
# # Online Retail

# %%
access_url = 'http://pbpython.com/market-basket-analysis.html'
db_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_excel(db_url)
# Out:
# c:\Users\mcoel\Documents\self_repos\Colab-AI-PucMinas\.venv\Lib\site-packages\openpyxl\packaging\core.py:99: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   now = datetime.datetime.utcnow()
# c:\Users\mcoel\Documents\self_repos\Colab-AI-PucMinas\.venv\Lib\site-packages\openpyxl\packaging\core.py:99: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   now = datetime.datetime.utcnow()

# %%
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
df.describe()
# Out:
#             Quantity  ...     CustomerID
# count  541909.000000  ...  406829.000000
# mean        9.552250  ...   15287.690570
# min    -80995.000000  ...   12346.000000
# 25%         1.000000  ...   13953.000000
# 50%         3.000000  ...   15152.000000
# 75%        10.000000  ...   16791.000000
# max     80995.000000  ...   18287.000000
# std       218.081158  ...    1713.600303
#
# [8 rows x 4 columns]

# %% [markdown]
# # Data prepare

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]
df.describe()
# Out:
#             Quantity  ...     CustomerID
# count  532621.000000  ...  397924.000000
# mean       10.239972  ...   15294.315171
# min     -9600.000000  ...   12346.000000
# 25%         1.000000  ...   13969.000000
# 50%         3.000000  ...   15159.000000
# 75%        10.000000  ...   16795.000000
# max     80995.000000  ...   18287.000000
# std       159.593551  ...    1713.169877
#
# [8 rows x 4 columns]

# %%
basket = (df[df['Country'] == 'France']
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                          0.0  ...                              0.0
# 536852                          0.0  ...                              0.0
# 536974                          0.0  ...                              0.0
# 537065                          0.0  ...                              0.0
# 537463                          0.0  ...                              0.0
# ...                             ...  ...                              ...
# 580986                          0.0  ...                              0.0
# 581001                          0.0  ...                              0.0
# 581171                          0.0  ...                              0.0
# 581279                          0.0  ...                              0.0
# 581587                          0.0  ...                              0.0
#
# [392 rows x 1563 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x > 0:
        return 1

# %%
basket_sets = basket.map(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)
basket_sets.head()

# %%
basket_sets.describe()

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
frequent_itemsets

# %%
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1)
rules

# %%
rules[(rules['lift'] >= 6) & (rules['confidence']) >= 0.8]
# Out:
#                                           antecedents  ... zhangs_metric
# 0                         (ALARM CLOCK BAKELIKE PINK)  ...      0.964734
# 1                        (ALARM CLOCK BAKELIKE GREEN)  ...      0.959283
# 2                          (ALARM CLOCK BAKELIKE RED)  ...      0.976465
# 3                        (ALARM CLOCK BAKELIKE GREEN)  ...      0.979224
# 4                          (ALARM CLOCK BAKELIKE RED)  ...      0.960466
# 5                         (ALARM CLOCK BAKELIKE PINK)  ...      0.968652
# 16                    (SET/6 RED SPOTTY PAPER PLATES)  ...      0.956140
# 17               (SET/20 RED RETROSPOT PAPER NAPKINS)  ...      0.961765
# 18                      (SET/6 RED SPOTTY PAPER CUPS)  ...      0.993343
# 19                    (SET/6 RED SPOTTY PAPER PLATES)  ...      0.981725
# 20  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...  ...      0.953488
# 21  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...  ...      0.967949
# 22  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...  ...      0.956294
# 23                      (SET/6 RED SPOTTY PAPER CUPS)  ...      0.995904
# 24                    (SET/6 RED SPOTTY PAPER PLATES)  ...      0.996251
# 25               (SET/20 RED RETROSPOT PAPER NAPKINS)  ...      0.964706
#
# [16 rows x 10 columns]
